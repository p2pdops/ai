# %% [markdown]
# # Week-9
#
# ## Aim: Implement a single neural network and test for different logic gates.

# %% [markdown]
# ![p2.png](data:image/png;base64,...)

# %% [markdown]
# (a) AND Gate

# %% [markdown]
# t represents biased value(-1.5)
#
# ![p3.png](data:image/png;base64,...)

# %%
# And gate
import numpy as np
# define Unit Step Function
def unitStep(v):
	if v >= 0:
		return 1
	else:
		return 0

# design Perceptron Model
def perceptronModel(x, w, b):
	v = np.dot(w, x) + b
	y = unitStep(v)
	return y

# AND  Logic Function
# w1 = 1, w2 = 1, b = -1.5
def AND_logicFunction(x):
	w = np.array([1, 1])
	b = -1.5
	return perceptronModel(x, w, b)
# testing the Perceptron Model
test1 = np.array([0, 1])
test2 = np.array([1, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 0])

print(f"AND{test1} : {AND_logicFunction(test1)}") 
print(f"AND{test2} : {AND_logicFunction(test2)}")
print(f"AND{test3} : {AND_logicFunction(test3)}")
print(f"AND{test4} : {AND_logicFunction(test4)}")
# Out:
# AND[0 1] : 0
# AND[1 1] : 1
# AND[0 0] : 0
# AND[1 0] : 0

# %% [markdown]
# (b) OR Gate

# %% [markdown]
# ![Screenshot 2021-09-23 at 6.35.00 PM.png](data:image/png;base64,...)

# %%
#0r gate 
import numpy as np
def unitStep(v):
	if v >= 0:
		return 1
	else:
		return 0
def perceptronModel(x, w, b):
	v = np.dot(w, x) + b
	y = unitStep(v)
	return y
# OR Logic Function
# w1 = 1, w2 = 1, b = -0.5
def OR_logicFunction(x):
	w = np.array([1, 1])
	b = -0.5
	return perceptronModel(x, w, b)
# testing the Perceptron Model
test1 = np.array([0, 1])
test2 = np.array([1, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 0])

print(f"OR{test1} : {OR_logicFunction(test1)}") 
print(f"OR{test2} : {OR_logicFunction(test2)}")
print(f"OR{test3} : {OR_logicFunction(test3)}")
print(f"OR{test4} : {OR_logicFunction(test4)}")
# Out:
# OR[0 1] : 1
# OR[1 1] : 1
# OR[0 0] : 0
# OR[1 0] : 1
